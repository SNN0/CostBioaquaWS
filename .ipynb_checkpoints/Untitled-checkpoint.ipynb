# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------------------- -------------------- 4.7/9.8 MB 28.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.8 MB 20.3 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 15.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 14.9 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
# ...

# %%
# Veri manipülasyonu için pandas
import pandas as pd

# Sayısal işlemler için numpy
import numpy as np

# Statik görselleştirmeler için matplotlib ve seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# İnteraktif görselleştirmeler için plotly
import plotly.express as px

# Grafikler için varsayılan ayarları belirleyelim
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (15, 7)

print("Kütüphaneler başarıyla yüklendi.")
# Out:
# Kütüphaneler başarıyla yüklendi.

# %%
# Veri setinin bulunduğu dosya yolunu belirtin. 
# Dosya bu notebook ile aynı klasördeyse sadece adını yazmak yeterlidir.
file_path = 'data/Sensor_data_for_30_cm.xlsx'

# Excel dosyasını oku
try:
    df = pd.read_excel(file_path)
    print("Veri seti başarıyla yüklendi.")
    # Verinin ilk 5 satırını göster
    display(df.head())
except FileNotFoundError:
    print(f"HATA: '{file_path}' dosyası bulunamadı. Lütfen dosya yolunu kontrol edin.")
# Out:
# HATA: 'data/Sensor_data_for_30_cm.xlsx' dosyası bulunamadı. Lütfen dosya yolunu kontrol edin.
